# %%
import sys
sys.path.append('../raft/')

import core.datasets as datasets

import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img_path = r'/home/mnegru/repos/optical-flow-dnn/raft/datasets/HD1K/hd1k_flow_uncertainty/flow_unc/000000_0010.png'

# %%
flow_uncertainty_img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)

# %%
type(flow_uncertainty_img)
# Out:
# numpy.ndarray

# %%
flow_uncertainty_img.dtype
# Out:
# dtype('uint16')

# %%
flow_uncertainty = flow_uncertainty_img / 256.0

# %%
flow_uncertainty.min()
# Out:
# 0.0

# %%
flow_uncertainty.max()
# Out:
# 5.078125

# %%
plt.imshow(flow_uncertainty)
